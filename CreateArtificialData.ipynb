# %%
import pandas as pd
import random 
import numpy as np
import string
from random import shuffle

# %%
lower_alphabet = string.ascii_lowercase

# %%
all_prices = []
for i in range(len(lower_alphabet)):
    prices = [random.uniform(1,100) for j in range(365)]
    all_prices.append(prices)

# %%
data_frame = pd.DataFrame(np.array(all_prices).T, columns=list(lower_alphabet))

# %%
display(data_frame.head())
# Out:
#            a          b          c          d          e          f  \
# 0  16.112046  45.043323  34.760161  39.080611  23.954685  59.517495
# 1  18.429321  67.311355  44.498426  62.534986  12.756834  49.769261
# 2  86.581969  49.917271  39.222873  33.325479  50.416215  22.831300
# 3  10.734337  41.297918  70.549311  79.919217  90.904817  48.060837
# 4  74.938456  59.663504  91.711841  33.510676   2.696736  30.944351
#
#            g          h          i          j  ...          q          r  \
# 0  12.044223   5.229402  71.401346  96.184750  ...  19.321955  13.011552
# 1  61.952343  23.156132  71.480424  60.940044  ...  22.971109  26.196641
# 2  54.743900  51.541679  84.115995  57.526369  ...  47.516906  49.370913
# 3  12.803529  90.108719  93.583950  35.204966  ...  61.709816  26.702644
# 4  39.451443  12.786377  14.650758  26.243615  ...  34.008573  11.440238
#
#            s          t          u          v          w          x  \
# ...

# %%
data_frame.to_excel(r'data/tickers_prices2.xlsx', index=False)
